# %%
import geopandas as gpd
import pandas as pd
import matplotlib as plt
import folium
import pyproj
from shapely.geometry import Point, Polygon, LineString

# %%
station = pd.read_csv('../station_coordinate.csv')

# %%
station = station.drop(columns = ['code', 'line'])
station
# Out:
#        name        lat         lng
# 0        녹양  37.759380  127.042292
# 1        남영  37.541021  126.971300
# 2        용산  37.529849  126.964561
# 3       노량진  37.514219  126.942454
# 4        대방  37.513342  126.926382
# ..      ...        ...         ...
# 725  지식정보단지  37.378384  126.645168
# 726   인천대입구  37.386007  126.639484
# 727   센트럴파크  37.393054  126.634729
# 728  국제업무지구  37.399907  126.630347
# 729   간석오거리  37.467048  126.707938
#
# [730 rows x 3 columns]

# %%
ddarung = pd.read_csv('../따릉이정보_수정.csv', encoding = 'euc-kr')
ddarung['shortest_subway'] = ""
ddarung
# Out:
#       Unnamed: 0            보관소(대여소)명  자치구                             상세주소  \
# 0              0          경복궁역 7번출구 앞  종로구  서울특별시 종로구 사직로 지하130 경복궁역 7번출구 앞
# 1              1          경복궁역 4번출구 뒤  종로구  서울특별시 종로구 사직로 지하130 경복궁역 4번출구 뒤
# 2              2          광화문역 1번출구 앞  종로구       서울특별시 종로구 세종대로 지하189 세종로공원
# 3              3               종로구청 옆  종로구               서울특별시 종로구 세종로 84-1
# 4              4            서울역사박물관 앞  종로구      서울특별시 종로구 새문안로 55 서울역사박물관 앞
# ...          ...                  ...  ...                              ...
# 2714        2714           명일역 3번출구 옆  강동구                    강동구 명일동 303-7
# 2715        2715              상일파출소 옆  강동구                    강동구 상일동 520-1
# 2716        2716      강변그대가리버뷰 입구 맞은편  강동구                    강동구 천호동 250-7
# 2717        2717                방아삼거리  강동구                    강동구 둔촌동 118-2
# 2718        2718   강동농협 버스정류소 앞(광채빌라)  강동구                   강동구 암사동 488-21
#
#              위도          경도 shortest_road    법정동 shortest_subway
# 0     37.575794  126.971451        사직로12길    내자동
# 1     37.575947  126.974060           사직로    적선동
# 2     37.571770  126.974663       세종대로23길    당주동
# 3     37.572559  126.978332          종로1길    세종로
# 4     37.570000  126.971100         경희궁1길  신문로2가
# ...         ...         ...           ...    ...             ...
# 2714  37.551426  127.144211          양재대로    명일동
# 2715  37.556553  127.165878        고덕로79길    상일동
# 2716  37.548164  127.122574           선사로    천호동
# 2717  37.523281  127.146133        동남로43길    둔촌동
# 2718  37.547966  127.135162       구천면로47길    암사동
#
# [2719 rows x 9 columns]

# %%
def getShorestDistanceStation(point): #subway
    distances = road_crs.geometry.distance(point)
    return road_crs.iloc[distances.idxmin()]['RN'], distances.min(), distances.idxmin()

# %%
import warnings
warnings.filterwarnings(action='ignore')

for index, row in ddarung.iterrows():
    output = getShorestDistanceStation(Point(row['경도'], row['위도']))
    ddarung['shortest_road'][index] = output[0]
    
    print(str(index) + " " + row['보관소(대여소)명'] + " -> " + output[0])
    
ddarung
